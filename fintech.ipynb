# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import rayleigh 
import numpy as np 
import matplotlib.pyplot as plt
quantile = np.arange (0.01, 10, 0.05) 

a, b = 4, 3
  
for i in range(3):
    a += 1
    R = rayleigh.pdf(a, b, quantile) 
    plot = plt.plot(quantile, R)
    plt.grid()
